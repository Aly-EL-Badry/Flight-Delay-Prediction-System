# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("../../../data/raw/airports.csv")
df
# Out:
#     IATA_CODE                              AIRPORT  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 0                         Allentown    PA     USA  40.65236  -75.44040
# 1                           Abilene    TX     USA  32.41132  -99.68190
# 2                       Albuquerque    NM     USA  35.04022 -106.60919
# ...

# %%
df["CITY"].nunique()
# Out:
# 308

# %%
df["STATE"].nunique()
# Out:
# 54

# %%
df["COUNTRY"].nunique()
# Out:
# 1

# %% [markdown]
# ## Conclusion
# - from this experiment i noted that we have 54 state that may effect the delay of flight.
# - but all the flights are from the same country so we will not use it in the main notebook.
# - also they are mostly from different city so this info wont be usefull to us.

# %%
Important_states = df[["IATA_CODE", "STATE"]]
Important_states
# Out:
#     IATA_CODE STATE
# 0         ABE    PA
# 1         ABI    TX
# 2         ABQ    NM
# 3         ABR    SD
# 4         ABY    GA
# ..        ...   ...
# 317       WRG    AK
# 318       WYS    MT
# 319       XNA    AR
# 320       YAK    AK
# 321       YUM    AZ
#
# [322 rows x 2 columns]

# %%
# save the important states
Important_states.to_csv("../../../data/processed/important_states.csv", index=False)
